# %% [markdown]
# # Marvel vs. DC - IMDB & Rotten Tomatoes Data Cleaner

# %% [markdown]
# Import tools needed

# %%
import os
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %% [markdown]
# Import CSV

# %%
csvfile = "clean_MvDC_df_copy.csv"
marvel_data = pd.read_csv(csvfile, encoding='utf-8')
marvel_data.head()
# Out:
#                        title  year                      genre  runtime  \
# 0            Captain America  1944  Action, Adventure, Sci-Fi      244
# 1  Superman and the Mole-Men  1951   Action, Adventure, Drama       58
# 2          Batman: The Movie  1966   Adventure, Comedy, Crime      105
# 3                   Superman  1978   Action, Adventure, Drama      143
# 4                Superman II  1980  Action, Adventure, Sci-Fi      127
#
#   mpa_rating  imdb_rating  imdb_gross             director  tomato_meter  \
# 0   Approved          5.5           0        Elmer Clifton             0
# 1     Passed          5.7           0           Lee Sholem             0
# 2         PG          6.5           0  Leslie H. Martinson            79
# 3         PG          7.3   134220000       Richard Donner            94
# 4         PG          6.8   108190000       Richard Lester            86
#
#    tom_aud_score  entity  universe_code  id             star_1  \
# ...

# %% [markdown]
# Isolate Marvel Movies

# %%
marvel_only = marvel_data.loc[marvel_data['entity'] == 'MARVEL', :]
marvel_only.head()
# Out:
#               title  year                      genre  runtime mpa_rating  \
# 0   Captain America  1944  Action, Adventure, Sci-Fi      244   Approved
# 8   Howard the Duck  1986  Action, Adventure, Comedy      110         PG
# 16            Blade  1998     Action, Horror, Sci-Fi      120          R
# 17            X-Men  2000  Action, Adventure, Sci-Fi      104      PG-13
# 18         Blade II  2002    Action, Fantasy, Horror      117          R
#
#     imdb_rating  imdb_gross            director  tomato_meter  tom_aud_score  \
# 0           5.5           0       Elmer Clifton             0             82
# 8           4.7    16300000       Willard Huyck            13             38
# 16          7.1    70090000  Stephen Norrington            55             78
# 17          7.4   157300000        Bryan Singer            82             83
# 18          6.7    82350000  Guillermo del Toro            57             68
#
# ...

# %% [markdown]
# Export to CSV

# %%
marvel_only.to_csv("machinelearning_marvel.csv", index=False, header=True)
